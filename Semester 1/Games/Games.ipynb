# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
df = pd.read_json("games.json")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 97410 entries, 0 to 97409
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        97410 non-null  int64
#  1   name                      97404 non-null  object
#  2   release_date              97410 non-null  object
#  3   estimated_owners          97410 non-null  object
#  4   peak_ccu                  97410 non-null  int64
#  5   required_age              97410 non-null  int64
#  6   price                     97410 non-null  float64
#  7   dlc_count                 97410 non-null  int64
#  8   main_description          92540 non-null  object
#  9   supported_languages       97410 non-null  object
#  10  full_audio_languages      97410 non-null  object
#  11  reviews                   10125 non-null  object
#  12  header_image              97410 non-null  object
# ...

# %% [markdown]
# ##### This was the first assignment : Find this ID

# %%
df[df["ID"] == 22380]
# Out:
#          ID                name  release_date   estimated_owners  peak_ccu  \
# 1025  22380  Fallout: New Vegas  Oct 19, 2010  2000000 - 5000000      5776
#
#       required_age  price  dlc_count  \
# 1025            16   9.99          0
#
#                                        main_description  \
# 1025  Welcome to Vegas. New Vegas. It’s the kind of ...
#
#                                     supported_languages  ...  \
# 1025  ['English', 'French', 'German', 'Italian', 'Sp...  ...
#
#      average_playtime_forever average_playtime_2weeks median_playtime_forever  \
# 1025                     3044                     112                     976
#
#      packages              developers          publishers  \
# 1025      153  Obsidian Entertainment  Bethesda Softworks
#
#                                              categories      genres  \
# 1025  Single-player,Steam Achievements,Partial Contr...  Action,RPG
#
#                                                    tags  \
# ...

# %%
df.loc[1025]
# Out:
# ID                                                                      22380
# name                                                       Fallout: New Vegas
# release_date                                                     Oct 19, 2010
# estimated_owners                                            2000000 - 5000000
# peak_ccu                                                                 5776
# required_age                                                               16
# price                                                                    9.99
# dlc_count                                                                   0
# main_description            Welcome to Vegas. New Vegas. It’s the kind of ...
# supported_languages         ['English', 'French', 'German', 'Italian', 'Sp...
# full_audio_languages                                                       []
# reviews                                                                  None
# ...

# %%
#if "Call of Duty" in df["name"]

# %%
df.head(50)
# Out:
#          ID                                       name  release_date  \
# 0     20200                           Galactic Bowling  Oct 21, 2008
# 1    655370                               Train Bandit  Oct 12, 2017
# 2   1732930                               Jolt Project  Nov 17, 2021
# 3   1355720                                   Henosis™  Jul 23, 2020
# 4   1139950                      Two Weeks in Painland   Feb 3, 2020
# 5   1469160                             Wartune Reborn  Feb 26, 2021
# 6   1659180                                  TD Worlds   Jan 9, 2022
# 7   1968760         Legend of Rome - The Wrath of Mars   May 5, 2022
# 8   1178150                      MazM: Jekyll and Hyde   Apr 2, 2020
# 9    320150                  Deadlings: Rotten Edition  Nov 11, 2014
# 10  1026420                                     WARSAW   Oct 2, 2019
# 11   485000                             Cthulhu Realms   Jul 1, 2016
# 12  1620060                          Clockwork Dungeon  Aug 27, 2021
# ...

# %%
example = {1: "A", 2: ["B", "C"]}

# %%
example[2]
# Out:
# ['B', 'C']

# %%
sns.scatterplot(data=df, x="price", y="metacritic_score")
# Out:
# <Axes: xlabel='price', ylabel='metacritic_score'>

# %%
sns.scatterplot(data=df, x="metacritic_score", y="price")
# Out:
# <Axes: xlabel='metacritic_score', ylabel='price'>

# %%
df["price"].max()
# Out:
# 999.98

# %%
df["price"].mean()
# Out:
# 7.086261574786982

# %%
df[df["price"] == 999.98]
# Out:
#             ID                                name  release_date  \
# 81901  2499620                   The Leverage Game  Aug 25, 2023
# 82971  2504210  The Leverage Game Business Edition  Aug 26, 2023
#
#       estimated_owners  peak_ccu  required_age   price  dlc_count  \
# 81901        0 - 20000         0             0  999.98          0
# 82971        0 - 20000         0             0  999.98          0
#
#                                         main_description  \
# 81901  The Leverage Game is a board game in which pla...
# 82971  The Leverage Game is a board game in which pla...
#
#            supported_languages  ... average_playtime_forever  \
# 81901  ['English', 'Japanese']  ...                        0
# 82971  ['English', 'Japanese']  ...                        0
#
#       average_playtime_2weeks median_playtime_forever packages developers  \
# 81901                       0                       0        0   A&S Inc.
# ...

# %%
#dfCleaned = df.drop([81901, 82971], inplace=True)
dfCleaned = dfCleaned.reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 #dfCleaned = df.drop([81901, 82971], inplace=True)
# ----> 2 dfCleaned = dfCleaned.reset_index()
#
# NameError: name 'dfCleaned' is not defined

# %% [markdown]
# ## This is for the scatterplot
# #### An outlier would definitely the game that costs 999.98, dollars, which is very expensive compared to the average price of games, which is around $7

# %%
df.head(50)

# %% [markdown]
# ### This was for exit ticket last class!!!!!!!

# %%
sns.scatterplot(data=df, x="required_age", y="recommendations")

# %%
sns.scatterplot(data=df, x="recommendations", y="required_age")

# %%
df["recommendations"].max()

# %%
df["recommendations"].mean()

# %% [markdown]
# ### Class 9/23/24

# %%
sns.scatterplot(data=df, x="price", y="recommendations")

# %% [markdown]
# ### The scatterplot above does not have a direction, really, since it is not going in a positive nor negative direction. It is non-linear, if you were to draw a line, it wouldn't go through almost all the dots. There wouldn't be much of a relationship, it has a weak relationship. Between the price and recommendation, it can be seen that the cheaper a game, the more recommendations it has. The 999 dollar game has 0 recommendations meanwhile the games that are less than 100 dollars have more recommendations.

# %%
df[df["recommendations"] == df["recommendations"].max()]

# %%
sns.scatterplot(data=df, x="estimated_owners", y="required_age")

# %%
df["estimated_owners"].info

# %%
sns.barplot(data=df, x="estimated_owners", y="required_age")

# %%
df.info()

# %%
sns.scatterplot(data=df, x="positive", y="negative")

# %%
pearsonr(df["positive"], df["negative"])

# %% [markdown]
# #### The scatterplot has a positive direction with a somewhat linear form and a relatively strong relationship.  The correlation value is 0.7, which is close to 1, so it does have a decent and firm relationship whith a few outliers. It can be seen that there are more negative reviews than there are positive.

# %%
#df.corr(method='pearson', min_periods=1, numeric_only=False)

# Teacher Live

# %%
df.corr(method="pearson")

# %%
subDF = df[["positive", "negative"]]

# %%
subDF.corr(method="pearson")

# %% [markdown]
# #### Looking at the scatterplot for positive vs. negative, there appears to be a postive relatioshiip. There are a few outliers to consider when calculating the pearson correlation coefficient. With outliers, the pearson correlation coeffice found between positive and negative reviews is 0.78, which suggests the relationship between these variables is strong and positive. this means that as the number of positive reviews increases for a game, the numbber of negative reviews decreases.

# %%
sns.scatterplot(data=df, x="achievements", y="recommendations")

# %%
pearsonr(df["achievements"], df["recommendations"])

# %%
df["achievements"].max()

# %%
df[df["achievements"] == 9821]

# %%
cleanDF = df.drop([50218])

# %%
sns.scatterplot(data=cleanDF, x="achievements", y="recommendations")

# %%
pearsonr(cleanDF["achievements"], cleanDF["recommendations"])

# %% [markdown]
# ### The relationship between the achievements made and the amount of recommendations games receive is a non-linear with no direction, weak related scatterplot. The correlation coefficient is 0.013, which makes the relationship extremely weak, to the point that there is no relationship.

# %% [markdown]
# ### EXIT TICKET 9/23

# %%
sns.scatterplot(data=df, x="average_playtime_forever", y="recommendations")
# Out:
# <Axes: xlabel='average_playtime_forever', ylabel='recommendations'>

# %%
df["average_playtime_forever"].max()
# Out:
# 145727

# %%
df[df["average_playtime_forever"] == 145727]
# Out:
#             ID     name  release_date estimated_owners  peak_ccu  \
# 10228  1071100  Boom 3D  Jun 19, 2019    20000 - 50000       199
#
#        required_age  price  dlc_count  \
# 10228             0  16.99          0
#
#                                         main_description  \
# 10228  Boom 3D is a pro audio enhancement app that ha...
#
#                                      supported_languages  ...  \
# 10228  ['English', 'French', 'German', 'Spanish - Spa...  ...
#
#       average_playtime_forever average_playtime_2weeks  \
# 10228                   145727                      21
#
#       median_playtime_forever packages                             developers  \
# 10228                  145727       21  Global Delight Technologies Pvt. Ltd.
#
#                                   publishers  categories  \
# 10228  Global Delight Technologies Pvt. Ltd.        None
#
#                            genres                              tags  \
# ...

# %%
cleanerDF = df.drop([10228])

# %%
sns.scatterplot(data=cleanerDF, x="average_playtime_forever", y="recommendations")
# Out:
# <Axes: xlabel='average_playtime_forever', ylabel='recommendations'>

# %%
pearsonr(cleanerDF["average_playtime_forever"], cleanerDF["recommendations"])
# Out:
# PearsonRResult(statistic=0.2029244092764991, pvalue=0.0)
