# %%
from bs4 import BeautifulSoup
import requests
import random

# %% [markdown]
# ### I would choose Colorado School of Mines
# ### Expected value of Mines vs. Boulder.

# %%
url = "https://collegescorecard.ed.gov/school/?126775-Colorado-School-of-Mines"
response = requests.get(url)
html = response.text
soup = BeautifulSoup(html, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html data-html-server-rendered="true" data-vue-tag="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" lang="en">
# <head>
# ...

# %%
for h2 in h2s:
    print(h2.text)

# %% [markdown]
# ### Exit ticket 11/22/24

# %% [markdown]
# ### Columbia University

# %%
#Annual Cost : $ 23,497

#CS median earnings: $ 204,511
#Graduation Rate: 92%

#Cost all 4 years(Bachelors)
calc = 23497 * 4
print(calc)

# How much you'll earn during 40 years minus the cost of paying your college tuition
calc2 = 204511 * 40 - 93988
print(calc2)

print("---------------")


# Expectancy by multiplying the earnings with the graduation rate, what are the chances of actually earning that given the grad rate
calc3 = 204511 * .92
print(calc3)
# The expectancy multiplied by the years and subtracting the tuition cost
calc4 = 188150.12 * 40 - 93988
print(calc4)
# Out:
# 93988
# 8086452
# ---------------
# 188150.12
# 7432016.8

# %% [markdown]
# ### You'll earn 8,086,452 dollars in a 40 year career(no expectancy)
# ### You'll earn 7,432,016.8 dollars in a 40 year career(expectancy)

# %% [markdown]
# ### New York University

# %%
#Annual Cost: $32,462
#CS median earnings $149,736
#Graduation Rate: 86%

#Cost all 4 years
NYUcost = 32462 * 4
print(NYUcost)

# How much you'll earn in 40 years, subtracting your cost of tuition
NYU_earn = 149736 * 40 - 129848
print(NYU_earn)

print("-----------")

# Multiplying the median earning with the graduation rate
grad_expect = 149736 * .86
print(grad_expect)

#Now multiply the number above with 40 years while subtracting the money you owe
NYU_career = 128772.96 * 40 - 129848
print(NYU_career)
# Out:
# 129848
# 5859592
# -----------
# 128772.95999999999
# 5021070.4

# %% [markdown]
# ### You'll earn 5,859,592 dollars in 40 years( no expectancy)
# ### You'll earn 5,021,070.4 dollars in 40 years(expectancy)

# %%
### Now subtract both careers
print("No expectancy: ", 8086452 - 5859592)
print("Expectancy: ", 7432016.8 - 5021070.4)
# Out:
# No expectancy:  2226860
# Expectancy:  2410946.3999999994

# %% [markdown]
# #### You'd make 2,226,860 more at Columbia
# #### You'd make 2,410,946 more at Columbia taking in account the graduation rate.

# %% [markdown]
# ### Class 11/26/24
# ### Expected Value = probability x value
