# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data= pd.read_csv("titanic.csv")
boaty= pd.read_csv("estonia.csv")
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.loc[99]
# Out:
# PassengerId                  100
# Survived                       0
# Pclass                         2
# Name           Kantor, Mr. Sinai
# Sex                         male
# Age                         34.0
# SibSp                          1
# Parch                          0
# Ticket                    244367
# Fare                        26.0
# Cabin                        NaN
# Embarked                       S
# Name: 99, dtype: object

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.loc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
data.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data[data["Age"].isin([18])]
# Out:
#      PassengerId  Survived  Pclass  \
# 38            39         0       3
# 49            50         0       3
# 144          145         0       2
# 175          176         0       3
# 204          205         1       3
# 228          229         0       2
# 311          312         1       1
# 371          372         0       3
# 385          386         0       2
# 417          418         1       2
# 424          425         0       3
# 505          506         0       1
# 585          586         1       1
# 651          652         1       2
# 654          655         0       3
# 675          676         0       3
# 677          678         1       3
# 688          689         0       3
# 700          701         1       1
# 702          703         0       3
# 757          758         0       2
# 775          776         0       3
# 786          787         1       3
# 807          808         0       3
# 834          835         0       3
# ...

# %%
data.loc[5, 'Age'] = 28

# %%
data.loc[5]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                        28.0
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                       NaN
# Embarked                      Q
# Name: 5, dtype: object

# %%
count = 0
for person in data["Age"]:
    if person > 18:
        count = count + 1
count
# Out:
# 576

# %%
count = (data["Age"] > 18).sum()

# %%
print(count)
# Out:
# 576

# %%
count = 0
for person in data["Sex"]:
    if person == "male":
        count = count + 1
        
count = (count /len(data)) * 100
count
# Out:
# 64.75869809203144

# %%
print((data[data['Sex'] == 'male'].shape[0]/len(data))*100)
# Out:
# 64.75869809203144

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          715 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#new_data = data[['Embarked']]      WORKS I think
#print("New Data Frame")
#print(new_data)

# %%
classes = {"CLASS":[], "Frequency":[]}
countFirst = 0
countSecond = 0
countThird = 0
for ticket in data["Pclass"]:
    if ticket == 1:
        countFirst = countFirst + 1
    elif ticket == 2:
        countSecond = countSecond + 1
    elif ticket == 3:
        countThird == countThird + 1
classes["CLASS"].append("First")
classes["CLASS"].append("Second")
classes["CLASS"].append("Third")
classes["Frequency"].append(countFirst)
classes["Frequency"].append(countSecond)
classes["Frequency"].append(countThird)
classes
# Out:
# {'CLASS': ['First', 'Second', 'Third'], 'Frequency': [216, 184, 0]}

# %%
freqTable = pd.DataFrame(classes)
freqTable
# Out:
#     CLASS  Frequency
# 0   First        216
# 1  Second        184
# 2   Third          0

# %%
freqTable["Percent"] = (freqTable["Frequency"] / len(data)) * 100

# %%
freqTable.head()
# Out:
#     CLASS  Frequency    Percent
# 0   First        216  24.242424
# 1  Second        184  20.650954
# 2   Third          0   0.000000

# %%
#Checks the existence of such a thing. Our code*

# %%
(data['PassengerId'] == 528).any()
# Out:
# True

# %%
data[data['PassengerId'] == 528]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex  Age  SibSp  \
# 527          528         0       1  Farthing, Mr. John  male  NaN      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 527      0  PC 17483  221.7792   C95        S

# %%
#Class code(What the teacher does)... they did the same thing >:D

# %%
idx = 0
for person in data["Name"]:
    if "Fannie" in person:
        break
    idx += 1
data.loc[idx]
# Out:
# PassengerId                              707
# Survived                                   1
# Pclass                                     2
# Name           Kelly, Mrs. Florence "Fannie"
# Sex                                   female
# Age                                     45.0
# SibSp                                      0
# Parch                                      0
# Ticket                                223596
# Fare                                    13.5
# Cabin                                    NaN
# Embarked                                   S
# Name: 706, dtype: object

# %%
ctable = pd.crosstab(data["Sex"], data["Survived"] == 1, margins=True)
ctable
# Out:
# Survived  False  True  All
# Sex
# female       81   233  314
# male        468   109  577
# All         549   342  891

# %%
#for survival in data[ctable]:

# %%
cctable = pd.crosstab(data["Survived"] ==1, data["Sex"], margins=True)
cctable
# Out:
# Sex       female  male  All
# Survived
# False         81   468  549
# True         233   109  342
# All          314   577  891

# %%
# Extra Knowledge:

# %%
#for idx in range(len(data)):
    #print(data.loc[idx]["Sex"], data.loc[idx]["Survived"])
   # break

# %%
#Teacher

# %%
maleSurvive = 0
femaleSurvive = 0
maleDied = 0
femaleDied = 0
for idx in range(len(data)):
    if data.loc[idx]["Sex"] == "male" and data.loc[idx]["Survived"] == 0:
        maleDied += 1
    elif data.loc[idx]["Sex"] == "male" and data.loc[idx]["Survived"] == 1:
        maleSurvive += 1
    elif data.loc[idx]["Sex"] == "female" and data.loc[idx]["Survived"] == 0:
        femaleSurvive += 1
    elif data.loc[idx]["Sex"] == "female" and data.loc[idx]["Survived"] == 1:
        femaleSurvive += 1
conTable = pd.DataFrame({
    "Male": [maleSurvive, maleDied],
    "Female": [femaleSurvive, femaleDied]
})
conTable.index = ["Survived", "Died"]
conTable.head()
# Out:
#           Male  Female
# Survived   109     314
# Died       468       0

# %%
sbuck = 0 #0-18
syoungling = 0 #19- 45
sfossil = 0 #46+

dbuck = 0
dyoungling = 0
dfossil = 0

bucktotal = 0
younglingtotal = 0
fossiltotal = 0

allPeople = 0
allPeopleSurvived = 0
allPeopleDied = 0 

for idx in range(len(data)):
    if data.loc[idx]["Age"] <= 18 and data.loc[idx]["Survived"] == 0:
        dbuck += 1
        bucktotal += 1
        allPeople += 1
        allPeopleSurvived += 1
        allPeopleDied += 1
    elif data.loc[idx]["Age"] <= 18 and data.loc[idx]["Survived"] == 1:
        sbuck += 1
        bucktotal += 1
        allPeople += 1
        allPeopleSurvived += 1
        allPeopleDied += 1
    elif data.loc[idx]["Age"] > 18 and data.loc[idx]["Age"] <= 45 and data.loc[idx]["Survived"] == 0:
        dyoungling += 1
        younglingtotal += 1 
        allPeople += 1
        allPeopleSurvived += 1
        allPeopleDied += 1
    elif data.loc[idx]["Age"] > 18 and data.loc[idx]["Age"] <= 45 and data.loc[idx]["Survived"] == 1:
        syoungling += 1
        younglingtotal += 1
        allPeople += 1
        allPeopleSurvived += 1
        allPeopleDied += 1
    elif data.loc[idx]["Age"] >= 46 and data.loc[idx]["Survived"] == 0:
        dfossil += 1
        fossiltotal += 1
        allPeople += 1
        allPeopleSurvived += 1
        allPeopleDied += 1
    elif data.loc[idx]["Age"] >= 46 and data.loc[idx]["Survived"] == 1:
        sfossil += 1
        fossiltotal += 1
        allPeople += 1
        allPeopleSurvived += 1
        allPeopleDied += 1
conTable = {
    "Buck": [sbuck/bucktotal * 100 , dbuck/bucktotal * 100],
    "Youngling": [syoungling/younglingtotal * 100, dyoungling/younglingtotal * 100],
    "Fossil" : [sfossil/fossiltotal * 100, dfossil/fossiltotal * 100],
    "Total": [allPeopleSurvived/allPeople * 100, allPeopleDied/allPeople* 100]
}

data2 = pd.DataFrame(conTable)
data2.index = ["Survived", "Died"]
data2.head()
# Out:
#                Buck  Youngling     Fossil  Total
# Survived  50.359712  38.477801  37.623762  100.0
# Died      49.640288  61.522199  62.376238  100.0

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#contingencyTable = pd.crosstab(data["Embarked"], data["Survived"])
#contingencyTable = ['Total'] = contingencyTable.sum(axis=1)

#total = contingencyTable.sum().sum()
#relativeTable["total"] = (contingencyTable.sum(axis=1) / total) * 100
#relativeTable = contingencyTable / total

# %%
#relativeTable

# %%
#Teacher Live example

# %%
survived = {"S": 0, "C": 0, "Q": 0, "U": 0}
died = {"S": 0, "C": 0, "Q": 0, "U": 0}
for idx in range(len(data)):
    city = data.loc[idx]["Embarked"]
    if data.loc[idx]["Survived"] == 1:
        if city in ["S", "C", "Q"]:
            survived[city] += 1
        else:
            survived["U"] += 1
    else:
        if city in ["S", "C", "Q"]:
            died[city] += 1
        else:
            died["U"] += 1
conTable = {
    "S": [survived["S"]/(survived["S"] + died["S"]) * 100, died["S"], survived["S"] + died["S"]],
    "Q": [survived["Q"]/(survived["Q"] + died["Q"]) * 100, died["Q"], survived["Q"] + died["Q"]],
    "C": [survived["C"], died["C"], survived["C"] + died["C"]],
    "U": [survived["U"], died["U"], survived["U"] + died["U"]],
    "Total": [survived["S"] + survived["Q"] + survived["C"] + survived["U"], 
              died["S"] + died["Q"] + died["C"] + died["U"], len(data)]
}
conTable = pd.DataFrame(conTable)
conTable.index = ["Survived", "Died", "Total"]
conTable.head()
# Out:
#                    S          Q    C  U  Total
# Survived   33.695652  38.961039   93  2    342
# Died      427.000000  47.000000   75  0    549
# Total     644.000000  77.000000  168  2    891

# %%
passengerClasses = {"First": 0, "Second": 0, "Third": 0}
for passenger in data["Pclass"]:
    if passenger == 1:
        passengerClasses["First"] += 1
    elif passenger == 2:
        passengerClasses["Second"] += 1
    elif passenger == 3:
        passengerClasses["Third"] += 1
percentClasses = {"First": (passengerClasses["First"]/len(data))*100,
                 "Second": (passengerClasses["Second"]/len(data)*100),
                 "Third": (passengerClasses["Third"]/len(data)*100)
                 }
freqTable = {
    "Classes": ["First", "Second", "Third"],
    "Percent": [percentClasses["First"], percentClasses["Second"], percentClasses["Third"]]
}
freqTable = pd.DataFrame(freqTable)
freqTable.head()
# Out:
#   Classes    Percent
# 0   First  24.242424
# 1  Second  20.650954
# 2   Third  55.106622

# %%
sns.barplot(data=freqTable, x="Classes", y="Percent")
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='Percent'>

# %%
survived = {"First": 0, "Second": 0, "Third": 0}
died = {"First": 0, "Second": 0, "Third": 0}
for idx in range(len(data)):
    passengerClass = data.loc[idx]["Pclass"]
    passengerSurvived = data.loc[idx]["Survived"]
    if passengerClass == 1 and passengerSurvived == 1:
        survived["First"] += 1
    elif passengerClass == 1 and passengerSurvived == 0:
        died["First"] += 1
    elif passengerClass == 2 and passengerSurvived == 1:
        survived["Second"] += 1
    elif passengerClass == 2 and passengerSurvived == 0:
        died["Second"] += 1
    elif passengerClass == 3 and passengerSurvived == 1:
        survived["Third"] += 1
    elif passengerClass == 3 and passengerSurvived == 0:
        died["Third"] += 1

# %%
classDF = {
    "Classes": ["First", "Second", "Third"],
    "Survived": [survived["First"], survived["Second"], survived["Third"]],
    "Died": [died["First"], died["Second"], died["Third"]]
}
classDF = pd.DataFrame(classDF)
classDF.head()
# Out:
#   Classes  Survived  Died
# 0   First       136    80
# 1  Second        87    97
# 2   Third       119   372

# %%
classDF = pd.melt(classDF, id_vars="Classes")
classDF = classDF.rename(columns={"variable": "Survived"})
classDF.head()
# Out:
#   Classes  Survived  value
# 0   First  Survived    136
# 1  Second  Survived     87
# 2   Third  Survived    119
# 3   First      Died     80
# 4  Second      Died     97

# %%
sns.catplot(data = classDF, x="Classes", y="value", hue="Survived", kind="bar")

# %%
counts = {}
for country in boaty['Country']:
    if country not in counts:
        counts[country] = 1
    else:
        counts[country] += 1
counts
boaty
# Out:
#      PassengerId  Country             Firstname  Lastname Sex  Age Category  \
# 0              1   Sweden           ARVID KALLE     AADLI   M   62        P
# 1              2  Estonia                   LEA   AALISTE   F   22        C
# 2              3  Estonia                  AIRI   AAVASTE   F   21        C
# 3              4   Sweden                  JURI     AAVIK   M   53        C
# 4              5   Sweden       BRITTA ELISABET  AHLSTROM   F   55        P
# ..           ...      ...                   ...       ...  ..  ...      ...
# 984          985   Sweden  ANNA INGRID BIRGITTA    OSTROM   F   60        P
# 985          986   Sweden          ELMAR MIKAEL       OUN   M   34        P
# 986          987   Sweden                   ENN   QUNAPUU   M   77        P
# 987          988   Sweden                    LY   GUNAPUU   F   87        P
# 988          989   Sweden                  CARL    OVBERG   M   42        P
#
#      Survived
# 0           0
# 1           0
# ...

# %%
freqTable = boaty ["Country"].value_counts().reset_index()
freqTable.columns = ["Country", "Counts"]
freqTable["Percent"] = (freqTable["Counts"] / len(boaty)) * 100

# %%
freqTable
# Out:
#           Country  Counts    Percent
# 0          Sweden     550  55.611729
# 1         Estonia     344  34.782609
# 2          Latvia      28   2.831143
# 3         Finland      16   1.617796
# 4          Russia      14   1.415571
# 5          Norway       9   0.910010
# 6         Germany       8   0.808898
# 7         Denmark       6   0.606673
# 8       Lithuania       4   0.404449
# 9   Great Britain       2   0.202224
# 10        Morocco       2   0.202224
# 11    Netherlands       2   0.202224
# 12         France       1   0.101112
# 13        Nigeria       1   0.101112
# 14         Canada       1   0.101112
# 15        Belarus       1   0.101112

# %%
#This was for a testing for an exit ticket

# %%
counts = {}
for country in boaty["Country"]:
    if country not in counts:
        counts[country] = 1
    else:
        counts[country] +=1 
for country in counts:
    counts[country]=(counts[country]/len(boaty)*100)

# %%
counts
# Out:
# {'Sweden': 55.61172901921132,
#  'Estonia': 34.78260869565217,
#  'Latvia': 2.8311425682507583,
#  'Russia': 1.4155712841253791,
#  'Germany': 0.8088978766430739,
#  'Finland': 1.6177957532861478,
#  'Great Britain': 0.20222446916076847,
#  'Morocco': 0.20222446916076847,
#  'Denmark': 0.6066734074823054,
#  'France': 0.10111223458038424,
#  'Netherlands': 0.20222446916076847,
#  'Norway': 0.910010111223458,
#  'Lithuania': 0.40444893832153694,
#  'Nigeria': 0.10111223458038424,
#  'Canada': 0.10111223458038424,
#  'Belarus': 0.10111223458038424}

# %%
# THIS was for the exit ticket,

# %%
child = 0 #0-18
adult = 0 #19-55
elderly = 0 #56+



for idx in range(len(boaty)):
    if boaty.loc[idx]["Age"] <= 18:
        child += 1
    elif boaty.loc[idx]["Age"] > 18 and boaty.loc[idx]["Age"] <= 55:
        adult += 1       
    elif boaty.loc[idx]["Age"] >= 56:
        elderly += 1
age_groups = ['Child (0-18)', 'Adult (19-55)', 'Elderly (56+)']
counts = [child, adult, elderly]

frequency_table = pd.DataFrame({
    'Age Group': age_groups,
    'Count': counts
})

# %%
print(frequency_table)
# Out:
#        Age Group  Count
# 0   Child (0-18)     42
# 1  Adult (19-55)    661
# 2  Elderly (56+)    286

# %%
freqTable = boaty ["Sex"].value_counts().reset_index()
freqTable.columns = ["Female", "Male"]
freqTable
# Out:
#   Female  Male
# 0      M   503
# 1      F   486

# %% [markdown]
# ### This is for an exit ticket 8/26

# %%
frequency = pd.crosstab(boaty['Category'], boaty["Survived"])
frequency
# Out:
# Survived    0   1
# Category
# C         154  39
# P         698  98

# %%
survived = {"Passenger": 0, "Crew": 0}
died = {"Passenger": 0, "Crew": 0}

totalPeople = 0
totalS = 0
totalD = 0 

for idx in range(len(boaty)):
    type = boaty.loc[idx]["Category"]
    personSurvived = boaty.loc[idx]["Survived"]
    if type == "P" and personSurvived == 1:
        survived["Passenger"] += 1
        totalPeople += 1
        totalS += 1
        totalD += 1
    elif type == "P" and personSurvived == 0:
        died["Passenger"] += 1
        totalPeople += 1
        totalS += 1
        totalD += 1
    elif type == "C" and personSurvived == 1:
        survived["Crew"] += 1
        totalPeople += 1
        totalS += 1
        totalD += 1
    elif type == "C" and personSurvived == 0:
        died["Crew"] += 1
        totalPeople += 1
        totalS += 1
        totalD += 1

# %%
personDF = {
    "Type": ["Passenger", "Crew"],
    "Survived": [survived["Passenger"]/len(boaty) * 100, survived["Crew"]/len(boaty) * 100],
    "Died": [died["Passenger"]/len(boaty) * 100, died["Crew"]/len(boaty) * 100],
    "Total": [totalD/totalPeople * 100, totalS/totalPeople * 100]
}
personDF = pd.DataFrame(personDF)
personDF.head()
# Out:
#         Type  Survived       Died  Total
# 0  Passenger  9.908999  70.576340  100.0
# 1       Crew  3.943377  15.571284  100.0

# %%
boats={
    'Age Group': ['child', 'adult'],
    'Survived': [3, 134],
    'Died': [21, 831]
}
age_survival = pd.DataFrame(boats)
age_survival = pd.melt(age_survival, id_vars = "Age Group")
age_survival = age_survival.rename(columns={"variable": "Survival"})

# %%
sns.catplot(data=age_survival, x="Age Group", y="value", hue="Survival", kind="bar")

# %%
passengerCountry = {"Sweden": 0, "Estonia": 0, "Russia": 0, "Germany": 0}
for passenger in boaty["Country"]:
    if passenger == "Sweden":
        passengerCountry["Sweden"] += 1
    elif passenger == "Estonia":
        passengerCountry["Estonia"] += 1
    elif passenger == "Russia":
        passengerCountry["Russia"] += 1
    elif passenger == "Germany":
        passengerCountry["Germany"] +=1
percentCountry = {"Sweden": (passengerCountry["Sweden"]/len(boaty))*100,
                 "Estonia": (passengerCountry["Estonia"]/len(boaty)*100),
                 "Russia": (passengerCountry["Russia"]/len(boaty)*100),
                  "Germany": (passengerCountry["Germany"]/len(boaty)*100)
                 }
mesaFrecuencia = {
    "Country": ["Sweden", "Estonia", "Russia", "Germany"],
    "Survivors": [percentCountry["Sweden"], percentCountry["Estonia"], percentCountry["Russia"], percentCountry["Germany"]]
}
mesaFrecuencia = pd.DataFrame(mesaFrecuencia)
#mesaFrecuencia.head()

# %%
sns.barplot(data=freqTable, x="Country", y="Survivors")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23096\2592378912.py in <module>
# ----> 1 sns.barplot(data=freqTable, x="Country", y="Survivors")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
# ...

# %%
boaty["Country"].unique()
